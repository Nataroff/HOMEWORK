# %% [markdown]
# # Домашняя работа №2

# %%
import numpy as np
from scipy.optimize import approx_fprime
from PIL import Image

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Придумайте функции со следующими свойствами (в a) b) c) область определения X любая, какая вам удобна, главное - функция с нужными свойствами):
#
# a) бесконечное количество локальных экстремумов
#
# b) 2 локальных экстремума
#
# с) 3 локальных экстремума
#
# d*) область определения функции - 1 точка

# %% [markdown]
# **Решение**

# %%
image = Image.open('Расчет_0.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=434x174 at 0x26F3A788B88>

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Посчитайте 1-ую и 2-ую производные функции (на бумажке):
#
# $f(x) = sin^2(2x+1)$

# %% [markdown]
# **Решение**

# %%
image_1 = Image.open('Расчет_1.png')
image_1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=454x106 at 0x26F3A81B9C8>

# %% [markdown]
# ### Задание 3:
# Посчитайте частные производные функции в точкe
# (на бумажке или в LaTeX и на numpy):

# %% [markdown]
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$ в точке $(1,2)$

# %% [markdown]
# **Решение на "бумажке".**

# %%
image_2 = Image.open('Расчет_2.png')
image_2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=821x246 at 0x26F3A8250C8>

# %% [markdown]
# **Решение numpy**

# %%
def func(x):
    "Coordinate vector `x` should be an array of size two."
    return 2 * x[0]**2*x[1]**3 + 1 / x[0] + x[1]**2*x[0] + 7

# %%
x = np.array([1,2])
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(x, func, [eps, eps])
# Out:
# array([35.00000024, 28.00000024])

# %% [markdown]
# ### Задание 4:
#
# Градиентный спуск своими руками

# %%
from scipy.optimize import minimize, approx_fprime, fmin, brute

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

# %%
x = np.array([100, 200])
lr = 0.1
eps = np.sqrt(np.finfo(float).eps)

# %%
for i in range(100):
    # Calculate gradient
    grad = approx_fprime(x, f, [eps, eps])
    
    # Update x with gradient
    x = x - lr * grad

# %%
print("Минимум достигается в: ", x)
print("Значение функции в минимуме: ", f(x))
# Out:
# Минимум достигается в:  [1.29197811e-08 3.32901401e-08]
# Значение функции в минимуме:  1.2751541739575636e-15

# %% [markdown]
# Проверка с помощью встроенной функции scipy:

# %%
minimize(f, x, method='nelder-mead', options={'xtol': 1e-8, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
#  final_simplex: (array([[1.29197811e-08, 3.32901401e-08],
#        [1.35657701e-08, 3.32901401e-08],
#        [1.29197811e-08, 3.49546472e-08]]), array([1.27515417e-15, 1.29226355e-15, 1.38874810e-15]))
#            fun: 1.2751541739575636e-15
#        message: 'Optimization terminated successfully.'
#           nfev: 3
#            nit: 1
#         status: 0
#        success: True
#              x: array([1.29197811e-08, 3.32901401e-08])
